# %%
import matplotlib.pyplot as plt
import pandas as pd
import pylab as pl
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv("D:\helpSarah\car.csv")

# take a look at the dataset
df.head()
# Out:
#    car_ID                   CarName fueltype aspiration  enginesize  \
# 0       1        alfa-romero giulia      gas        std         130
# 1       2       alfa-romero stelvio      gas        std         130
# 2       3  alfa-romero Quadrifoglio      gas          x         152
# 3       4               audi 100 ls      gas        std         109
# 4       5                audi 100ls      gas        std         136
#
#    boreratio  stroke  compressionratio  horsepower  peakrpm  citympg  \
# 0       3.47    2.68               9.0         111     5000       21
# 1       3.47    2.68               9.0         111     5000       21
# 2       2.68    3.47               9.0         154     5000       19
# 3       3.19    3.40              10.0         102     5500       24
# 4       3.19    3.40               8.0         115     5500       18
#
#    highwaympg  price
# 0          27  13495
# 1          27  16500
# 2          26  16500
# 3          30  13950
# 4          22  17450

# %%
missing_data = df.isnull()
missing_data.sum()
# Out:
# car_ID              0
# CarName             0
# fueltype            0
# aspiration          0
# enginesize          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
df.describe()
# Out:
#            car_ID  enginesize   boreratio      stroke  compressionratio  \
# count  205.000000  205.000000  205.000000  205.000000        205.000000
# mean   103.000000  126.907317    3.329756    3.255415         10.142537
# std     59.322565   41.642693    0.270844    0.313597          3.972040
# min      1.000000   61.000000    2.540000    2.070000          7.000000
# 25%     52.000000   97.000000    3.150000    3.110000          8.600000
# 50%    103.000000  120.000000    3.310000    3.290000          9.000000
# 75%    154.000000  141.000000    3.580000    3.410000          9.400000
# max    205.000000  326.000000    3.940000    4.170000         23.000000
#
#        horsepower      peakrpm     citympg  highwaympg
# count  205.000000   205.000000  205.000000  205.000000
# mean   104.117073  5125.121951   24.570732   29.965854
# std     39.544167   476.985643    7.463054    8.503391
# min     48.000000  4150.000000    0.000000    0.000000
# ...

# %%
df['price'].value_counts()
# Out:
# price
# *        6
# 7898     2
# 5572     2
# 7775     2
# 7957     2
#         ..
# 35056    1
# 40960    1
# 45400    1
# 16503    1
# 22625    1
# Name: count, Length: 186, dtype: int64

# %%
df.replace("*", np.nan, inplace = True)
df.head(5)
# Out:
#    car_ID                   CarName fueltype aspiration  enginesize  \
# 0       1        alfa-romero giulia      gas        std         130
# 1       2       alfa-romero stelvio      gas        std         130
# 2       3  alfa-romero Quadrifoglio      gas          x         152
# 3       4               audi 100 ls      gas        std         109
# 4       5                audi 100ls      gas        std         136
#
#    boreratio  stroke  compressionratio  horsepower  peakrpm  citympg  \
# 0       3.47    2.68               9.0         111     5000       21
# 1       3.47    2.68               9.0         111     5000       21
# 2       2.68    3.47               9.0         154     5000       19
# 3       3.19    3.40              10.0         102     5500       24
# 4       3.19    3.40               8.0         115     5500       18
#
#    highwaympg  price
# 0          27  13495
# 1          27  16500
# 2          26  16500
# 3          30  13950
# 4          22  17450

# %%
df['price'].value_counts()
# Out:
# price
# 8921     2
# 8845     2
# 7775     2
# 5572     2
# 18150    2
#         ..
# 35056    1
# 40960    1
# 45400    1
# 16503    1
# 22625    1
# Name: count, Length: 185, dtype: int64

# %%
df.describe()
# Out:
#            car_ID  enginesize   boreratio      stroke  compressionratio  \
# count  205.000000  205.000000  205.000000  205.000000        205.000000
# mean   103.000000  126.907317    3.329756    3.255415         10.142537
# std     59.322565   41.642693    0.270844    0.313597          3.972040
# min      1.000000   61.000000    2.540000    2.070000          7.000000
# 25%     52.000000   97.000000    3.150000    3.110000          8.600000
# 50%    103.000000  120.000000    3.310000    3.290000          9.000000
# 75%    154.000000  141.000000    3.580000    3.410000          9.400000
# max    205.000000  326.000000    3.940000    4.170000         23.000000
#
#        horsepower      peakrpm     citympg  highwaympg
# count  205.000000   205.000000  205.000000  205.000000
# mean   104.117073  5125.121951   24.570732   29.965854
# std     39.544167   476.985643    7.463054    8.503391
# min     48.000000  4150.000000    0.000000    0.000000
# ...

# %%
missing_data = df.isnull()
missing_data.sum()
# Out:
# car_ID              0
# CarName             0
# fueltype            0
# aspiration          0
# enginesize          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               6
# dtype: int64

# %%
# simply drop whole row with NaN in "price" column
df.dropna(subset=["price"], axis=0, inplace=True)

df.tail()
# Out:
#      car_ID          CarName fueltype aspiration  enginesize  boreratio  \
# 199     200     volvo diesel      gas      turbo         130       3.62
# 200     201  volvo 145e (sw)        x        std         141       3.78
# 201     202      volvo 144ea      gas      turbo         141       3.78
# 203     204        volvo 246   diesel      turbo         145       3.01
# 204     205      volvo 264gl      gas      turbo         141       3.78
#
#      stroke  compressionratio  horsepower  peakrpm  citympg  highwaympg  price
# 199    3.15               7.5         162     5100       17          22  18950
# 200    3.15               9.5         114     5400       23          28  16845
# 201    3.15               8.7         160     5300       19           0  19045
# 203    3.40              23.0         106     4800        0          27  22470
# 204    3.15               9.5         114     5400       19          25  22625

# %%
df.describe()
# Out:
#            car_ID  enginesize   boreratio      stroke  compressionratio  \
# count  199.000000  199.000000  199.000000  199.000000        199.000000
# mean   102.844221  126.608040    3.332161    3.256382         10.184020
# std     59.033211   41.448241    0.270652    0.316597          4.022409
# min      1.000000   61.000000    2.540000    2.070000          7.000000
# 25%     52.500000   97.500000    3.150000    3.110000          8.600000
# 50%    103.000000  120.000000    3.310000    3.290000          9.000000
# 75%    153.500000  141.000000    3.585000    3.410000          9.400000
# max    205.000000  326.000000    3.940000    4.170000         23.000000
#
#        horsepower      peakrpm     citympg  highwaympg
# count  199.000000   199.000000  199.000000  199.000000
# mean   103.678392  5116.331658   24.577889   29.964824
# std     39.366282   481.052204    7.451033    8.518771
# min     48.000000  4150.000000    0.000000    0.000000
# ...

# %%
print(df.dtypes)
df.head()
# Out:
# car_ID                int64
# CarName              object
# fueltype             object
# aspiration           object
# enginesize            int64
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price                object
# dtype: object
#    car_ID                   CarName fueltype aspiration  enginesize  \
# 0       1        alfa-romero giulia      gas        std         130
# 1       2       alfa-romero stelvio      gas        std         130
# 2       3  alfa-romero Quadrifoglio      gas          x         152
# 3       4               audi 100 ls      gas        std         109
# 4       5                audi 100ls      gas        std         136
#
#    boreratio  stroke  compressionratio  horsepower  peakrpm  citympg  \
# 0       3.47    2.68               9.0         111     5000       21
# ...

# %%
df[["price"]] = df[["price"]].astype("float")
print(df.dtypes)
df.head()
# Out:
# car_ID                int64
# CarName              object
# fueltype             object
# aspiration           object
# enginesize            int64
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# dtype: object
#    car_ID                   CarName fueltype aspiration  enginesize  \
# 0       1        alfa-romero giulia      gas        std         130
# 1       2       alfa-romero stelvio      gas        std         130
# 2       3  alfa-romero Quadrifoglio      gas          x         152
# 3       4               audi 100 ls      gas        std         109
# 4       5                audi 100ls      gas        std         136
#
#    boreratio  stroke  compressionratio  horsepower  peakrpm  citympg  \
# 0       3.47    2.68               9.0         111     5000       21
# ...

# %%
cdf = df[['enginesize', 'price']]
cdf.head(9)
# Out:
#    enginesize    price
# 0         130  13495.0
# 1         130  16500.0
# 2         152  16500.0
# 3         109  13950.0
# 4         136  17450.0
# 5         136  15250.0
# 6         136  17710.0
# 7         136  18920.0
# 8         131  23875.0

# %%
viz = cdf[['enginesize', 'price']]
viz.hist()
plt.show()

# %%
plt.scatter(cdf.enginesize, cdf.price,  color='blue')
plt.xlabel("enginesize")
plt.ylabel("price")
plt.show()

# %%
msk = np.random.rand(len(df)) < 0.8
msk
train = cdf[msk]
test = cdf[~msk]

# %%
plt.scatter(train.enginesize, train.price,  color='blue')
plt.xlabel("enginesize")
plt.ylabel("price")
plt.show()

# %%
from sklearn import linear_model
regr = linear_model.LinearRegression()
train_x = np.asanyarray(train[['enginesize']])
train_y = np.asanyarray(train[['price']])
regr.fit(train_x, train_y)
# The coefficients
print ('Coefficients: ', regr.coef_)
print ('Intercept: ',regr.intercept_)
# Out:
# Coefficients:  [[165.39688675]]
# Intercept:  [-7873.25222636]

# %%
plt.scatter(train.enginesize, train.price,  color='blue')
plt.plot(train_x, regr.coef_[0][0]*train_x + regr.intercept_[0], '-r')
plt.xlabel("enginesize")
plt.ylabel("price")
# Out:
# Text(0, 0.5, 'price')

# %%
from sklearn.metrics import r2_score

test_x = np.asanyarray(test[['enginesize']])
test_y = np.asanyarray(test[['price']])
test_y_ = regr.predict(test_x)

print("Mean absolute error: %.2f" % np.mean(np.absolute(test_y_ - test_y)))
print("Residual sum of squares (MSE): %.2f" % np.mean((test_y_ - test_y) ** 2))
print("R2-score: %.2f" % r2_score(test_y , test_y_) )
# Out:
# Mean absolute error: 1934.64
# Residual sum of squares (MSE): 8011679.16
# R2-score: 0.80

# %%
cdf = df[['enginesize','price','highwaympg','horsepower']]
cdf.head(9)
# Out:
#    enginesize    price  highwaympg  horsepower
# 0         130  13495.0          27         111
# 1         130  16500.0          27         111
# 2         152  16500.0          26         154
# 3         109  13950.0          30         102
# 4         136  17450.0          22         115
# 5         136  15250.0          25         110
# 6         136  17710.0          25         110
# 7         136  18920.0          25         110
# 8         131  23875.0          20         140

# %%
msk = np.random.rand(len(df)) < 0.8
train = cdf[msk]
test = cdf[~msk]

# %%
from sklearn import linear_model
regr = linear_model.LinearRegression()
x = np.asanyarray(train[[]])
y = np.asanyarray(train[['price']])
regr.fit (x, y)
# The coefficients
print ('Coefficients: ', regr.coef_)
# Out:
# Coefficients:  [[ 119.71975136 -101.62099317   44.98006622]]

# %%
from sklearn.metrics import r2_score

y_hat= regr.predict(test[['enginesize','highwaympg','horsepower']].values)
x = np.asanyarray(test[['enginesize','highwaympg','horsepower']])
y = np.asanyarray(test[['price']])

print("R2-score: %.2f" % r2_score(y , y_hat) )
# Out:
# R2-score: 0.75
