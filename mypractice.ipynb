# %%
import matplotlib.pyplot as plt
import pandas as pd
import pylab as pl
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv("D:\helpSarah\cars.csv")

# %%
df.head()
# Out:
#    price      brand    model  year   title_status  mileage   color  \
# 0   6300     toyota  cruiser  2008  clean vehicle   274117   black
# 1   2899       ford       se  2011            tbd   190552  silver
# 2   5350      dodge      mpv  2018  clean vehicle    39590  silver
# 3  25000       ford     door  2014  clean vehicle    64146    blue
# 4  27700  chevrolet     1500  2018  clean vehicle     6654     red
#
#         state country
# 0  new jersey     usa
# 1   tennessee     usa
# 2     georgia     usa
# 3    virginia     usa
# 4     florida     usa

# %%
df.describe()
# Out:
#               price         year       mileage
# count   2499.000000  2499.000000  2.499000e+03
# mean   18767.671469  2016.714286  5.229869e+04
# std    12116.094936     3.442656  5.970552e+04
# min        0.000000  1973.000000  0.000000e+00
# 25%    10200.000000  2016.000000  2.146650e+04
# 50%    16900.000000  2018.000000  3.536500e+04
# 75%    25555.500000  2019.000000  6.347250e+04
# max    84900.000000  2020.000000  1.017936e+06

# %%
df = df.loc[~((df['price'] == 0))]

# %%
df.describe()
# Out:
#               price         year       mileage
# count   2456.000000  2456.000000  2.456000e+03
# mean   19096.258550  2016.931189  5.011143e+04
# std    11962.176006     2.957497  5.460446e+04
# min       25.000000  1973.000000  0.000000e+00
# 25%    10500.000000  2016.000000  2.127675e+04
# 50%    17050.000000  2018.000000  3.504850e+04
# 75%    25800.000000  2019.000000  6.005075e+04
# max    84900.000000  2020.000000  1.017936e+06

# %%
df = df[df['title_status'] != 'tbd']

# %%
df.head(10)
# Out:
#     price      brand    model  year   title_status  mileage   color  \
# 0    6300     toyota  cruiser  2008  clean vehicle   274117   black
# 2    5350      dodge      mpv  2018  clean vehicle    39590  silver
# 3   25000       ford     door  2014  clean vehicle    64146    blue
# 4   27700  chevrolet     1500  2018  clean vehicle     6654     red
# 6    7300  chevrolet       pk  2010  clean vehicle   149050   black
# 7   13350        gmc     door  2017  clean vehicle    23525    gray
# 8   14600  chevrolet   malibu  2018  clean vehicle     9371  silver
# 9    5250       ford      mpv  2017  clean vehicle    63418   black
# 10  10400      dodge    coupe  2009  clean vehicle   107856  orange
# 11  12920        gmc      mpv  2017  clean vehicle    39650   white
#
#          state country
# 0   new jersey     usa
# 2      georgia     usa
# 3     virginia     usa
# 4      florida     usa
# 6      georgia     usa
# 7   california     usa
# 8      florida     usa
# 9        texas     usa
# ...

# %%
df['brand'].value_counts()
# Out:
# brand
# ford               1198
# dodge               414
# nissan              307
# chevrolet           278
# gmc                  38
# jeep                 28
# chrysler             17
# bmw                  16
# hyundai              15
# infiniti             12
# kia                  12
# buick                11
# honda                11
# mercedes-benz         9
# cadillac              9
# land                  4
# heartland             4
# acura                 3
# peterbilt             3
# audi                  3
# lexus                 2
# ram                   1
# maserati              1
# toyota                1
# lincoln               1
# harley-davidson       1
# jaguar                1
# mazda                 1
# Name: count, dtype: int64

# %%
df['title_status'].value_counts()
# Out:
# title_status
# clean vehicle        2279
# salvage insurance     122
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#               price         year       mileage
# count   2401.000000  2401.000000  2.401000e+03
# mean   19129.563932  2016.933361  5.004889e+04
# std    11972.110240     2.967416  5.479662e+04
# min       25.000000  1973.000000  0.000000e+00
# 25%    10500.000000  2016.000000  2.127800e+04
# 50%    17100.000000  2018.000000  3.504700e+04
# 75%    25900.000000  2019.000000  5.992400e+04
# max    84900.000000  2020.000000  1.017936e+06

# %%
dummy_variable_1 = pd.get_dummies(df["title_status"])
dummy_variable_1.head(20)
# Out:
#     clean vehicle  salvage insurance
# 0            True              False
# 2            True              False
# 3            True              False
# 4            True              False
# 6            True              False
# 7            True              False
# 8            True              False
# 9            True              False
# 10           True              False
# 11           True              False
# 12           True              False
# 13           True              False
# 14           True              False
# 15           True              False
# 16           True              False
# 17           True              False
# 18           True              False
# 19           True              False
# 20           True              False
# 21           True              False

# %%
# merge data frame "df" and "dummy_variable_1" 
df = pd.concat([df, dummy_variable_1], axis=1)

# %%
df.head()
# Out:
#    price      brand    model  year   title_status  mileage   color  \
# 0   6300     toyota  cruiser  2008  clean vehicle   274117   black
# 2   5350      dodge      mpv  2018  clean vehicle    39590  silver
# 3  25000       ford     door  2014  clean vehicle    64146    blue
# 4  27700  chevrolet     1500  2018  clean vehicle     6654     red
# 6   7300  chevrolet       pk  2010  clean vehicle   149050   black
#
#         state country  clean vehicle  salvage insurance
# 0  new jersey     usa           True              False
# 2     georgia     usa           True              False
# 3    virginia     usa           True              False
# 4     florida     usa           True              False
# 6     georgia     usa           True              False

# %%
dummy_variable_2 = pd.get_dummies(df["country"])
dummy_variable_2.head(20)
# Out:
#      canada   usa
# 0     False  True
# 2     False  True
# 3     False  True
# 4     False  True
# 6     False  True
# 7     False  True
# 8     False  True
# 9     False  True
# 10    False  True
# 11    False  True
# 12    False  True
# 13    False  True
# 14    False  True
# 15    False  True
# 16    False  True
# 17    False  True
# 18    False  True
# 19    False  True
# 20    False  True
# 21    False  True

# %%
# merge data frame "df" and "dummy_variable_2" 
df = pd.concat([df, dummy_variable_2], axis=1)

# %%
df.head()
# Out:
#    price      brand    model  year   title_status  mileage   color  \
# 0   6300     toyota  cruiser  2008  clean vehicle   274117   black
# 2   5350      dodge      mpv  2018  clean vehicle    39590  silver
# 3  25000       ford     door  2014  clean vehicle    64146    blue
# 4  27700  chevrolet     1500  2018  clean vehicle     6654     red
# 6   7300  chevrolet       pk  2010  clean vehicle   149050   black
#
#         state country  clean vehicle  salvage insurance   canada   usa
# 0  new jersey     usa           True              False    False  True
# 2     georgia     usa           True              False    False  True
# 3    virginia     usa           True              False    False  True
# 4     florida     usa           True              False    False  True
# 6     georgia     usa           True              False    False  True

# %%
cdf = df[['price', 'mileage']]
cdf.head(10)
# Out:
#     price  mileage
# 0    6300   274117
# 2    5350    39590
# 3   25000    64146
# 4   27700     6654
# 6    7300   149050
# 7   13350    23525
# 8   14600     9371
# 9    5250    63418
# 10  10400   107856
# 11  12920    39650

# %%
viz = cdf[['price', 'mileage']]
viz.hist()
plt.show()

# %%
plt.scatter(cdf.mileage, cdf.price,  color='blue')
plt.xlabel("mileage")
plt.ylabel("price")
plt.show()

# %%
msk = np.random.rand(len(df)) < 0.8
msk
train = cdf[msk]
test = cdf[~msk]

# %%
plt.scatter(train.mileage, train.price,  color='blue')
plt.xlabel("mileage")
plt.ylabel("price")
plt.show()

# %%
from sklearn import linear_model
regr = linear_model.LinearRegression()
train_x = np.asanyarray(train[['mileage']])
train_y = np.asanyarray(train[['price']])
regr.fit(train_x, train_y)
# The coefficients
print ('Coefficients: ', regr.coef_)
print ('Intercept: ',regr.intercept_)
# Out:
# Coefficients:  [[-0.08013016]]
# Intercept:  [23142.67528859]

# %%
plt.scatter(train.mileage, train.price,  color='blue')
plt.plot(train_x, regr.coef_[0][0]*train_x + regr.intercept_[0], '-r')
plt.xlabel("mileage")
plt.ylabel("price")
# Out:
# Text(0, 0.5, 'price')

# %%
from sklearn.metrics import r2_score

test_x = np.asanyarray(test[['mileage']])
test_y = np.asanyarray(test[['price']])
test_y_ = regr.predict(test_x)

print("Mean absolute error: %.2f" % np.mean(np.absolute(test_y_ - test_y)))
print("Residual sum of squares (MSE): %.2f" % np.mean((test_y_ - test_y) ** 2))
print("R2-score: %.2f" % r2_score(test_y , test_y_) )
# Out:
# Mean absolute error: 8621.83
# Residual sum of squares (MSE): 129547483.27
# R2-score: 0.15

# %%
cdf = df[['price', 'mileage', ' canada', ' usa', 'clean vehicle', 'salvage insurance']]
cdf.head(9)
# Out:
#     price  mileage   canada   usa  clean vehicle  salvage insurance
# 0    6300   274117    False  True           True              False
# 2    5350    39590    False  True           True              False
# 3   25000    64146    False  True           True              False
# 4   27700     6654    False  True           True              False
# 6    7300   149050    False  True           True              False
# 7   13350    23525    False  True           True              False
# 8   14600     9371    False  True           True              False
# 9    5250    63418    False  True           True              False
# 10  10400   107856    False  True           True              False

# %%
msk = np.random.rand(len(df)) < 0.8
train = cdf[msk]
test = cdf[~msk]

# %%
from sklearn import linear_model
regr = linear_model.LinearRegression()
x = np.asanyarray(train[['mileage', ' canada', ' usa', 'clean vehicle', 'salvage insurance']])
y = np.asanyarray(train[['price']])
regr.fit (x, y)
# The coefficients
print ('Coefficients: ', regr.coef_)
# Out:
# Coefficients:  [[-7.30052001e-02  4.87794396e+03 -4.87794396e+03  5.08392401e+03
#   -5.08392401e+03]]

# %%
from sklearn.metrics import r2_score

y_hat= regr.predict(test[['mileage', ' canada', ' usa', 'clean vehicle', 'salvage insurance']].values)
x = np.asanyarray(test[['mileage', ' canada', ' usa', 'clean vehicle', 'salvage insurance']])
y = np.asanyarray(test[['price']])

print("R2-score: %.2f" % r2_score(y , y_hat) )
# Out:
# R2-score: 0.19
